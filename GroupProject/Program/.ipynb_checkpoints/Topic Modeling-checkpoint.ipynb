# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import re
import matplotlib.pyplot as plt
import glob, os

# %%
#Combine all 3 Million Records to One Large Data Frame spread over Multiple .csv Files
df = pd.concat(map(pd.read_csv, glob.glob(os.path.join('', "*.csv"))))
df.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3267: DtypeWarning: Columns (0,15,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3267: DtypeWarning: Columns (10,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3267: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   external_author_id        author  \
# 0         2495567768  DAILYSANFRAN
# 1         2495567768  DAILYSANFRAN
# 2         2495567768  DAILYSANFRAN
# 3         2495567768  DAILYSANFRAN
# 4         2495567768  DAILYSANFRAN
#
#                                              content         region language  \
# 0  Police: Airline pilot found passed out in cock...  United States  English
# 1  Dashcam video shows man launching himself onto...  United States  English
# 2  Man Arrested For Setting Fire To South SF Medi...  United States  English
# 3  Practical tips to achieving your New Year's re...  United States  English
# 4  Couple disappears during trip to Big Sur https...  United States  English
#
#      publish_date  harvested_date  following  followers  updates  ...  \
# 0  1/2/2017 14:39  1/2/2017 14:39       4577      16782    34960  ...
# 1  1/2/2017 15:39  1/2/2017 15:39       4577      16782    34961  ...
# 2  1/2/2017 16:19  1/2/2017 16:19       4577      16782    34962  ...
# 3  1/2/2017 16:29  1/2/2017 16:29       4577      16782    34963  ...
# 4  1/2/2017 16:39  1/2/2017 16:39       4577      16781    34964  ...
#
#   account_type retweet  account_category new_june_2018  alt_external_id  \
# 0        local       0          NewsFeed             0       2495567768
# 1        local       0          NewsFeed             0       2495567768
# 2        local       0          NewsFeed             0       2495567768
# 3        local       0          NewsFeed             0       2495567768
# 4        local       0          NewsFeed             0       2495567768
#
#              tweet_id                                        article_url  \
# 0  815930489311789056  http://twitter.com/2495567768/statuses/8159304...
# 1  815945595546431488  http://twitter.com/2495567768/statuses/8159455...
# 2  815955659963432960  http://twitter.com/2495567768/statuses/8159556...
# 3  815958175593730049  http://twitter.com/2495567768/statuses/8159581...
# 4  815960697800626176  http://twitter.com/2495567768/statuses/8159606...
#
#                                           tco1_step1  \
# 0  https://twitter.com/DailySanFran/status/815930...
# 1  https://twitter.com/DailySanFran/status/815945...
# 2  https://twitter.com/DailySanFran/status/815955...
# 3  https://twitter.com/DailySanFran/status/815958...
# 4  https://twitter.com/DailySanFran/status/815960...
#
#                                           tco2_step1 tco3_step1
# 0  http://kron4.com/2017/01/02/police-airline-pil...        NaN
# 1  http://kron4.com/2017/01/02/dashcam-video-show...        NaN
# 2  http://sanfrancisco.cbslocal.com/2017/01/02/ma...        NaN
# 3  http://abc7news.com/society/practical-tips-to-...        NaN
# 4  http://kron4.com/2017/01/02/couple-disappears-...        NaN
#
# [5 rows x 21 columns]

# %%
# Convert Date Format to DateTime So that we can easily Filter Data based on time
df["publish_date"] = df["publish_date"].astype("datetime64")
# Out:
#   external_author_id        author  \
# 0         2495567768  DAILYSANFRAN
# 1         2495567768  DAILYSANFRAN
# 2         2495567768  DAILYSANFRAN
# 3         2495567768  DAILYSANFRAN
# 4         2495567768  DAILYSANFRAN
#
#                                              content         region language  \
# 0  Police: Airline pilot found passed out in cock...  United States  English
# 1  Dashcam video shows man launching himself onto...  United States  English
# 2  Man Arrested For Setting Fire To South SF Medi...  United States  English
# 3  Practical tips to achieving your New Year's re...  United States  English
# 4  Couple disappears during trip to Big Sur https...  United States  English
#
#          publish_date  harvested_date  following  followers  updates  ...  \
# 0 2017-01-02 14:39:00  1/2/2017 14:39       4577      16782    34960  ...
# 1 2017-01-02 15:39:00  1/2/2017 15:39       4577      16782    34961  ...
# 2 2017-01-02 16:19:00  1/2/2017 16:19       4577      16782    34962  ...
# 3 2017-01-02 16:29:00  1/2/2017 16:29       4577      16782    34963  ...
# 4 2017-01-02 16:39:00  1/2/2017 16:39       4577      16781    34964  ...
#
#   account_type retweet  account_category new_june_2018  alt_external_id  \
# 0        local       0          NewsFeed             0       2495567768
# 1        local       0          NewsFeed             0       2495567768
# 2        local       0          NewsFeed             0       2495567768
# 3        local       0          NewsFeed             0       2495567768
# 4        local       0          NewsFeed             0       2495567768
#
#              tweet_id                                        article_url  \
# 0  815930489311789056  http://twitter.com/2495567768/statuses/8159304...
# 1  815945595546431488  http://twitter.com/2495567768/statuses/8159455...
# 2  815955659963432960  http://twitter.com/2495567768/statuses/8159556...
# 3  815958175593730049  http://twitter.com/2495567768/statuses/8159581...
# 4  815960697800626176  http://twitter.com/2495567768/statuses/8159606...
#
#                                           tco1_step1  \
# 0  https://twitter.com/DailySanFran/status/815930...
# 1  https://twitter.com/DailySanFran/status/815945...
# 2  https://twitter.com/DailySanFran/status/815955...
# 3  https://twitter.com/DailySanFran/status/815958...
# 4  https://twitter.com/DailySanFran/status/815960...
#
#                                           tco2_step1 tco3_step1
# 0  http://kron4.com/2017/01/02/police-airline-pil...        NaN
# 1  http://kron4.com/2017/01/02/dashcam-video-show...        NaN
# 2  http://sanfrancisco.cbslocal.com/2017/01/02/ma...        NaN
# 3  http://abc7news.com/society/practical-tips-to-...        NaN
# 4  http://kron4.com/2017/01/02/couple-disappears-...        NaN
#
# [5 rows x 21 columns]

# %%
#Plot Entire data based on Months
number_plot = df["content"].groupby([df["publish_date"].dt.year, df["publish_date"].dt.month]).count().plot(kind="bar", figsize=(20,10))
number_plot.set_xlabel("Tweets")
number_plot.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#Important Observations 

# Ground work for the medling started way back in late 2014
# First Peak was around July 2015
# Consistent Tweets in the months leading upto the election (Peaks in November)
# Unexpected Result :
# Tweeting Increased after the elections suggesting that this not just election meddling but  
# a larger effort to undermine the politics in the US 
# Dive deeper with this information to find more Patterns


#Intresting Months 
# July 2015
# November 2015
# Semptember 2016
# October 2016
# November 2016
# August 2017

# %%
#Plot Entire data based on Months
number_plot = df["content"].groupby([df["publish_date"].dt.year, df["publish_date"].dt.month, df["publish_date"].dt.day  ]).count().plot(figsize=(20,10))
number_plot.set_xlabel("Tweets")
number_plot.set_ylabel("Count")
#number_plot.axes.get_xaxis().set_visible(False)
# Out:
# Text(0, 0.5, 'Count')

# %%
#We see a huge Spike in October 2016 Specifically, Oct 6 2016
# In Fact, Every Single Spike in this data Correlates to Some Global Event.

# %%
#Plot Entire data based on Months
number_plot = df["content"].groupby([df["region"]]).count().plot(kind="scatter", figsize=(20,10))
number_plot.set_xlabel("Tweets")
number_plot.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#Fetch English Tweets
df_english = df.loc[df['language'] == "English"]
df_english.count()
# Out:
# external_author_id    2116867
# author                2116867
# content               2116866
# region                2115731
# language              2116867
# publish_date          2116867
# harvested_date        2116867
# following             2116867
# followers             2116867
# updates               2116867
# post_type              852536
# account_type          2116867
# retweet               2116867
# account_category      2116867
# new_june_2018         2116867
# alt_external_id       2116867
# tweet_id              2116867
# article_url           2116867
# tco1_step1            1358060
# tco2_step1             450925
# tco3_step1              14075
# dtype: int64

# %%
#Account Types 
df_accountTypecount = df_english.groupby(['account_type'])['account_type'].count()
df_accountTypecount = pd.DataFrame({'account_type':df_accountTypecount.index, 'count':df_accountTypecount.values})
df_accountTypecount = df_accountTypecount.sort_values(by=['count'], ascending=False)
df_accountTypecount.head(20)
# Out:
#    account_type   count
# 11        Right  704953
# 15        local  458012
# 9          Left  422141
# 6     Hashtager  236092
# 16         news  138581
# 2    Commercial  112580
# 12      Russian   20015
# 8          Koch   10759
# 0             ?    6945
# 5        German    3567
# 7       Italian    1799
# 1        Arabic    1030
# 14   ZAPOROSHIA     172
# 13      Spanish      79
# 4        French      70
# 3        Ebola       70
# 10   Portuguese       2

# %%
# Accounts with Most Number of Followers
df_authors = df_english[['author','followers']].drop_duplicates(subset='author', keep="first")
df_authors_sorted = df_authors.sort_values(by=['followers'], ascending=False)
df_authors_sorted.head(10)
# Out:
#                 author  followers
# 8894        NOVOSTIMSK     206686
# 19650    KADIROVRUSSIA      90183
# 14135     MAXDEMENTIEV      90089
# 27991       NOVOSTISPB      82213
# 143658         TEN_GOP      63928
# 0          TODAYNYCITY      61789
# 193467      ELEVEN_GOP      59100
# 213445     JENN_ABRAMS      39014
# 128630    LAVROVMUESLI      35441
# 139147  PAMELA_MOORE13      33250

# %%
df_tweetcount = df_english.groupby(['author'])['author'].count()
df_tweetcount = pd.DataFrame({'Author':df_tweetcount.index, 'Count':df_tweetcount.values})
df_authors_sorted = df_tweetcount.sort_values(by=['Count'], ascending=False)
df_authors_sorted.head(10)
# Out:
#                Author  Count
# 737           EXQUOTE  53158
# 1815    SCREAMYMONKEY  43956
# 2115    WORLDNEWSPOLI  35082
# 126     AMELIEBALDWIN  34308
# 1989  TODAYPITTSBURGH  33377
# 1895    SPECIALAFFAIR  32416
# 1818     SEATTLE_POST  30680
# 1095  KANSASDAILYNEWS  28746
# 1755      ROOMOFRUMOR  28259
# 535      DAILYSANFRAN  27962

# %%
#Filter Tweets based on Important Months


#July 2015
start_date = '07-01-2015'
end_date = '07-31-2015'
df_Jul2015 = df_english.loc[(df_english['publish_date'] > start_date) & (df_english['publish_date'] <= end_date)]
df_Jul2015['tweet'] = df_Jul2015['content']

#November 2015
start_date = '11-01-2015'
end_date = '11-30-2015'
df_Nov2015 = df_english.loc[(df_english['publish_date'] > start_date) & (df_english['publish_date'] <= end_date)]
df_Nov2015['tweet'] = df_Nov2015['content']

#September 2016
start_date = '09-01-2016'
end_date = '09-30-2016'
df_Sep2016 = df_english.loc[(df_english['publish_date'] > start_date) & (df_english['publish_date'] <= end_date)]
df_Sep2016['tweet'] = df_Sep2016['content']

#October 2016
start_date = '10-01-2016'
end_date = '10-30-2016'
df_Oct2016 = df_english.loc[mask]
df_Oct2016['tweet'] = df_Oct2016['content']


#Novmber 2016
start_date = '11-01-2016'
end_date = '11-30-2016'
df_Nov2016 =df_english.loc[(df_english['publish_date'] > start_date) & (df_english['publish_date'] <= end_date)]
df_Nov2016['tweet'] = df_Nov2016['content']

#August 2017
start_date = '08-01-2017'
end_date = '08-30-2017'
df_Aug2017 = df_english.loc[(df_english['publish_date'] > start_date) & (df_english['publish_date'] <= end_date)]
df_Aug2017['tweet'] = df_Aug2017['content']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
number_plot = df_Jul2015["content"].groupby([df_Jul2015["publish_date"].dt.month, df_Jul2015["publish_date"].dt.day]).count().plot(kind="bar", figsize=(20,10))
number_plot.set_xlabel("Tweets")
number_plot.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#Cleaning Unstructured Text Data
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

# %%
#Data Cleaning and Pre Processing
# def remove_links(tweet):
#     '''Takes a string and removes web links from it'''
#     tweet = re.sub(r'http\S+', '', tweet) # remove http links
#     tweet = re.sub(r'bit.ly/\S+', '', tweet) # rempve bitly links
#     tweet = tweet.strip('[link]') # remove [links]
#     return tweet

# def remove_users(tweet):
#     '''Takes a string and removes retweet and @user information'''
#     tweet = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove retweet
#     tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove tweeted at
#     return tweet

# %%
 my_stopwords = nltk.corpus.stopwords.words('english')
# word_rooter = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem
# my_punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~•@'

# cleaning master function
# def clean_tweet(tweet, bigrams=False):
#     tweet = remove_users(tweet)
#     tweet = remove_links(tweet)
#     tweet = tweet.lower() # lower case
#     tweet = re.sub('['+my_punctuation + ']+', ' ', tweet) # strip punctuation
#     tweet = re.sub('\s+', ' ', tweet) #remove double spacing
#     tweet = re.sub('([0-9]+)', '', tweet) # remove numbers
#     tweet_token_list = [word for word in tweet.split(' ')
#                             if word not in my_stopwords] # remove stopwords

# #     tweet_token_list = [word_rooter(word) if '#' not in word else word
# #                         for word in tweet_token_list] # apply word rooter
#     if bigrams:
#         tweet_token_list = tweet_token_list+[tweet_token_list[i]+'_'+tweet_token_list[i+1]
#                                             for i in range(len(tweet_token_list)-1)]
#     tweet = ' '.join(tweet_token_list)
#     return tweet

from bs4 import BeautifulSoup
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
combined_pat = r'|'.join((pat1, pat2))
def clean_tweet(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    
    tweet_token_list = [word for word in words
                      if word not in my_stopwords] # remove stopwords
    
    return (" ".join(tweet_token_list)).strip()

# %%
df_Jul2015['clean_tweet'] = df_Jul2015.tweet.apply(clean_tweet)
# Out:
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://t.co/zuIzbpejyw" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://t.co/figQ9WcMBI" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://t.co/Zp8k6j1VhG" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://t.co/NeeCmAq0RO" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.9, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')

# apply transformation
tf = vectorizer.fit_transform(df_Jul2015['clean_tweet']).toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names()

# %%
from sklearn.decomposition import LatentDirichletAllocation

number_of_topics = 10
#LDA
model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)

# %%
model.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=10, n_jobs=None, n_topics=None, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]

    return pd.DataFrame(topic_dict)

# %%
no_top_words = 10
display_topics(model, tf_feature_names, no_top_words)
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0          life          1250.3          news          4720.3          news
# 1         right          1018.8         world          2524.5           man
# 2        health           951.5      politics          1400.3         local
# 3           new           834.2         trump          1214.9        police
# 4          know           773.1          iran          1102.1       topnews
# 5        always           492.9          says          1082.0     cleveland
# 6       someone           480.8          deal          1056.2         crime
# 7           via           448.6             u           898.5          year
# 8          must           420.1           new           683.4         woman
# 9        people           346.0         obama           635.8         miami
#
#   Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words Topic 4 weights  \
# 0          1874.7        sports          1225.9       workout          4312.5
# 1          1796.2            bb           981.1          diet          2719.1
# 2          1558.0            sp           967.1      exercise          1096.2
# 3          1218.7         obama           872.3           day          1055.8
# 4           866.9       america           664.1         going           862.3
# 5           849.7         video           538.8           lol           847.3
# 6           828.1          baby           537.4          even           726.9
# 7           659.8          tcot           532.2       fitness           664.9
# 8           624.2       planned           482.1           new           544.7
# 9           602.1    parenthood           419.1      tomorrow           542.4
#
#   Topic 5 words Topic 5 weights Topic 6 words Topic 6 weights Topic 7 words  \
# 0      exercise         10560.9        weight          9229.1       workout
# 1           one          1262.9          lose          6861.1          like
# 2          time          1164.3          need          2371.8          love
# 3             u           771.3          loss          2357.1       fitness
# 4          week           708.0           fat          1828.5          feel
# 5            go           631.1        trying           816.3           pre
# 6       fitness           628.5        really           656.5          well
# 7           get           592.4          want           644.9          good
# 8           let           485.7           way           562.6          want
# 9           see           474.3          help           539.4         night
#
#   Topic 7 weights    Topic 8 words Topic 8 weights Topic 9 words  \
# 0          4725.0            words          1257.1       workout
# 1          2768.0            money           767.7          good
# 2          1593.3           sports           538.4           get
# 3          1033.1               us           493.5         today
# 4           982.5   unitedstatesin           474.1            go
# 5           931.3  wasteamillionin           473.1          need
# 6           692.0            house           454.2       morning
# 7           631.0             news           449.7           got
# 8           554.9            white           400.5          time
# 9           499.9              buy           309.2           gym
#
#   Topic 9 weights
# 0         27875.7
# 1          3460.1
# 2          2448.0
# 3          2436.7
# 4          2254.6
# 5          1887.9
# 6          1806.1
# 7          1571.0
# 8          1296.3
# 9          1225.5

# %%
#NMF
from sklearn.decomposition import NMF
model = NMF(n_components=10, random_state=0, alpha=.1, l1_ratio=.5)
model.fit(tf)
# Out:
# NMF(alpha=0.1, beta_loss='frobenius', init=None, l1_ratio=0.5, max_iter=200,
#   n_components=10, random_state=0, shuffle=False, solver='cd', tol=0.0001,
#   verbose=0)

# %%
no_top_words = 10
display_topics(model, tf_feature_names, no_top_words)
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0       workout            22.4          lose            11.9      exercise
# 1         today             1.2        weight            11.7          like
# 2       morning             0.8          want             0.7           eat
# 3           pre             0.8        trying             0.7          time
# 4         great             0.7           eat             0.5           lol
# 5          time             0.7         wanna             0.4         today
# 6           day             0.6          like             0.4           day
# 7           got             0.6           lol             0.4          much
# 8          done             0.5          gain             0.4          diet
# 9          like             0.5          help             0.4         great
#
#   Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words Topic 4 weights  \
# 0            18.0          news            14.7          good            15.0
# 1             0.5         world             5.4         today             0.9
# 2             0.5     cleveland             1.2          feel             0.5
# 3             0.4          says             1.0       morning             0.4
# 4             0.4          iran             1.0           ass             0.4
# 5             0.4        police             1.0       fitness             0.4
# 6             0.4         state             1.0         feels             0.4
# 7             0.3          deal             0.8           got             0.4
# 8             0.3            us             0.7       feeling             0.4
# 9             0.3       islamic             0.6           day             0.3
#
#   Topic 5 words Topic 5 weights Topic 6 words Topic 6 weights Topic 7 words  \
# 0          need            15.2           get            14.3        weight
# 1        really             1.0          back             1.3          loss
# 2       partner             0.8          time             1.3          diet
# 3          diet             0.6       fitness             0.9          tips
# 4           fat             0.5           fat             0.7          best
# 5         buddy             0.5         gotta             0.6       program
# 6           new             0.4           let             0.5           fat
# 7          asap             0.3         ready             0.4          plan
# 8          back             0.3        trying             0.3           new
# 9       someone             0.3          home             0.3         great
#
#   Topic 7 weights Topic 8 words Topic 8 weights Topic 9 words Topic 9 weights
# 0             9.1             u            12.6            go            13.8
# 1             9.1        sports             4.2       fitness             2.3
# 2             0.8          like             3.5          diet             2.2
# 3             0.5      politics             3.1           gym             1.2
# 4             0.3           new             2.6          want             0.9
# 5             0.3          says             2.0           let             0.9
# 6             0.3         obama             1.9         wanna             0.8
# 7             0.2         trump             1.8          back             0.5
# 8             0.2            bb             1.6         gonna             0.5
# 9             0.2            sp             1.6         sleep             0.4

# %%
from gensim.models import doc2vec
from collections import namedtuple


docs = []
analyzedDocument = namedtuple('AnalyzedDocument', 'words tags')
for i, text in enumerate(doc1):
    words = text.lower().split()
    tags = [i]
    docs.append(analyzedDocument(words, tags))

# Train model (set min_count = 1, if you want the model to work with the provided example data set)

model = doc2vec.Doc2Vec(docs, size = 100, window = 300, min_count = 1, workers = 4)

# %%
#Major Topics of Discussions 
# 1. Weightloss
# 2. Trump Campaign
# 3. Planned Parenthood
# 4. Cleveland Police Shooting

# %%
df_Nov2015['clean_tweet'] = df_Nov2015.tweet.apply(clean_tweet)

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.9, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')

tf = vectorizer.fit_transform(df_Nov2015['clean_tweet']).toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.decomposition import LatentDirichletAllocation

number_of_topics = 10

model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)

# %%
model.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=10, n_jobs=None, n_topics=None, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
no_top_words = 20
display_topics(model, tf_feature_names, no_top_words)
# Out:
#    Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0              в          5586.0             с          6256.5             в
# 1             за          3967.9             и          3403.3             о
# 2             из          3017.5            на          2490.4            из
# 3              ©          2585.9             о          2469.8             с
# 4             на          2425.8            су          2458.8           сми
# 5          photo          1904.5             в          2186.0       человек
# 6             ap          1799.7            рф          2172.3        париже
# 7              и          1190.0        турции          1908.5           при
# 8              у          1014.1            по          1760.5          мали
# 9            сша           919.4           мид          1116.7       франции
# 10             с           828.5           #су          1111.9            во
# 11             »           709.2        россии           944.7      погибших
# 12          года           584.4   #ударвспину           899.6            до
# 13             к           538.8           для           885.8        власти
# 14      #новости           518.7            не           864.9           мвд
# 15        flickr           502.8         путин           855.0            не
# 16        россии           488.2             »           824.3        египта
# 17         метро           475.2            из           701.9         число
# 18        угрозы           467.0           что           650.6           сша
# 19            до           397.5          нато           643.7             и
#
#    Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words  \
# 0          12645.7   #demndebate          4129.1            на
# 1           2537.1    #demdebate          2747.1             в
# 2           1218.7     #politics           931.1             и
# 3           1127.1           say           782.3            не
# 4           1051.4           new           698.9             с
# 5           1022.8        attack           698.8             »
# 6            931.2          pari           658.1             а
# 7            924.0        carson           653.1           что
# 8            918.1            us           650.6           как
# 9            903.6         peopl           638.7            за
# 10           773.2          like           620.2           это
# 11           772.7             ’           610.9             я
# 12           587.4         obama           609.9           для
# 13           546.5         trump           595.1             у
# 14           537.9           get           468.2            то
# 15           530.9          want           455.5             к
# 16           496.3       #health           454.1            из
# 17           486.1         #tcot           449.1       украине
# 18           466.3         polic           448.5            но
# 19           460.9      #topnews           441.5             —
#
#    Topic 4 weights Topic 5 words Topic 5 weights Topic 6 words  \
# 0           9838.2             в         20954.5            по
# 1           3572.4            на          2636.4             в
# 2           2760.5        париже          2522.3  безопасности
# 3           2663.3             с          2122.5        россии
# 4           1886.1             и          1567.4        charli
# 5           1733.4            из          1446.5         hebdo
# 6           1285.4        россии          1239.1            от
# 7           1184.1            по          1093.2             и
# 8           1020.8        москве          1081.1          меры
# 9           1014.8             а          1079.9            на
# 10           905.7           сми          1047.7            не
# 11           840.8         после           978.7       украины
# 12           731.1      терактов           942.4            за
# 13           698.8         видео           874.9          wada
# 14           677.0            не           855.1            في
# 15           674.9       человек           844.5          дело
# 16           658.0            за           794.8       решение
# 17           629.4       полиция           758.5        назвал
# 18           570.8             о           744.1            من
# 19           540.5             к           718.9           boe
#
#    Topic 6 weights   Topic 7 words Topic 7 weights Topic 8 words  \
# 0           1722.8      #kochfarms          3988.0             в
# 1           1272.9           #news          2684.6         сирии
# 2            713.5         #turkey          2113.3            не
# 3            664.8         #sports          1590.2            иг
# 4            618.1           #usda          1563.1             с
# 5            590.1  #foodpoisoning          1309.1           что
# 6            556.6       thanksgiv          1188.1         путин
# 7            530.6        #walmart          1047.1            рф
# 8            501.1             #ny           859.1           сша
# 9            492.7             omg           813.1             и
# 10           471.4          #world           806.4            по
# 11           420.3           wooow           735.1        против
# 12           370.3           happi           711.1        россия
# 13           344.5           #fsis           650.1        россии
# 14           339.1    #dogthanking           619.1           вкс
# 15           324.9               u           571.9   террористов
# 16           298.6           #loca           568.7          игил
# 17           280.1               ’           533.6             о
# 18           273.1             man           519.8      владимир
# 19           268.1             say           519.4             к
#
#    Topic 8 weights Topic 9 words Topic 9 weights
# 0           4598.4         #news          1929.8
# 1           2973.8             в          1521.0
# 2           2382.1             —          1468.0
# 3           1898.8        #world           716.8
# 4           1885.4         polic           594.6
# 5           1795.8             и           484.3
# 6           1783.2          матч           481.8
# 7           1606.9          цска           429.1
# 8           1387.9          kill           423.8
# 9           1306.9             »           401.3
# 10          1270.5       «зенит»           380.5
# 11          1096.4        attack           330.0
# 12          1011.8         матча           329.3
# 13           997.6       suspect           328.4
# 14           588.1        онлайн           315.7
# 15           575.2          dead           299.7
# 16           507.2        arrest           263.6
# 17           488.7        ноября           261.8
# 18           446.8        airlin           253.1
# 19           442.6         shoot           247.3

# %%
#Major Topics of Discussions 
#Mostly Reverted back to Russian, 
#Food Poisoning, USDA 
#Paris 2015 Attacks (Russian)
#Democratic Debate

# %%
df_Oct2016['clean_tweet'] = df_Oct2016.tweet.apply(clean_tweet)

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.9, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')

tf = vectorizer.fit_transform(df_Oct2016['clean_tweet']).toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.decomposition import LatentDirichletAllocation

number_of_topics = 10

model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)

# %%
model.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=10, n_jobs=None, n_topics=None, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
no_top_words = 10
display_topics(model, tf_feature_names, no_top_words)
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0             в          5586.0             с          6256.5             в
# 1            за          3967.9             и          3403.3             о
# 2            из          3017.5            на          2490.4            из
# 3             ©          2585.9             о          2469.8             с
# 4            на          2425.8            су          2458.8           сми
# 5         photo          1904.5             в          2186.0       человек
# 6            ap          1799.7            рф          2172.3        париже
# 7             и          1190.0        турции          1908.5           при
# 8             у          1014.1            по          1760.5          мали
# 9           сша           919.4           мид          1116.7       франции
#
#   Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words Topic 4 weights  \
# 0         12645.7   #demndebate          4129.1            на          9838.2
# 1          2537.1    #demdebate          2747.1             в          3572.4
# 2          1218.7     #politics           931.1             и          2760.5
# 3          1127.1           say           782.3            не          2663.3
# 4          1051.4           new           698.9             с          1886.1
# 5          1022.8        attack           698.8             »          1733.4
# 6           931.2          pari           658.1             а          1285.4
# 7           924.0        carson           653.1           что          1184.1
# 8           918.1            us           650.6           как          1020.8
# 9           903.6         peopl           638.7            за          1014.8
#
#   Topic 5 words Topic 5 weights Topic 6 words Topic 6 weights   Topic 7 words  \
# 0             в         20954.5            по          1722.8      #kochfarms
# 1            на          2636.4             в          1272.9           #news
# 2        париже          2522.3  безопасности           713.5         #turkey
# 3             с          2122.5        россии           664.8         #sports
# 4             и          1567.4        charli           618.1           #usda
# 5            из          1446.5         hebdo           590.1  #foodpoisoning
# 6        россии          1239.1            от           556.6       thanksgiv
# 7            по          1093.2             и           530.6        #walmart
# 8        москве          1081.1          меры           501.1             #ny
# 9             а          1079.9            на           492.7             omg
#
#   Topic 7 weights Topic 8 words Topic 8 weights Topic 9 words Topic 9 weights
# 0          3988.0             в          4598.4         #news          1929.8
# 1          2684.6         сирии          2973.8             в          1521.0
# 2          2113.3            не          2382.1             —          1468.0
# 3          1590.2            иг          1898.8        #world           716.8
# 4          1563.1             с          1885.4         polic           594.6
# 5          1309.1           что          1795.8             и           484.3
# 6          1188.1         путин          1783.2          матч           481.8
# 7          1047.1            рф          1606.9          цска           429.1
# 8           859.1           сша          1387.9          kill           423.8
# 9           813.1             и          1306.9             »           401.3

# %%
#Major Topics of Discussions 
#Media bias Against White people
#Hurricane Matthew
#Police Brutality
#Turkey
#Better Alternative Debates

#Koch Farms Misinformation Campaign

# %%
df_Nov2016['clean_tweet'] = df_Nov2016.tweet.apply(clean_tweet)

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.9, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')

tf = vectorizer.fit_transform(df_Nov2016['clean_tweet']).toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.decomposition import LatentDirichletAllocation

number_of_topics = 15

model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)

# %%
model.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=15, n_jobs=None, n_topics=None, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
no_top_words = 20
display_topics(model, tf_feature_names, no_top_words)
# Out:
#    Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights  \
# 0            new          1351.9             в          5675.7
# 1           play          1142.6            на          1851.9
# 2          video          1013.8             с          1515.4
# 3           news           820.5             и           897.9
# 4           post           668.9            за           767.1
# 5            via           636.5            из           564.2
# 6          great           629.2       спасибо           454.4
# 7          music           616.8             »           370.3
# 8              ”           602.2             …           361.0
# 9              \           517.9             \           343.8
# 10       america           515.6        россии           334.4
# 11             ’           488.0         видео           326.7
# 12             #           407.0        ноября           319.0
# 13         black           378.3          фото           309.3
# 14         obama           358.7           кто           307.2
# 15           get           352.6    петербурге           258.3
# 16          make           327.4        москве           223.4
# 17          fake           316.1           под           208.4
# 18           got           315.5            по           206.3
# 19            ft           310.9       помощью           197.4
#
#          Topic 2 words Topic 2 weights         Topic 3 words Topic 3 weights  \
# 0                trump          6570.5                  vote          2045.0
# 1                    ’          2244.7               hillari          1573.8
# 2   #trumpforpresident          1791.1                 white          1327.6
# 3               presid          1209.9                 trump          1311.1
# 4                #maga          1157.8                 elect          1295.6
# 5               donald          1135.1               clinton          1208.8
# 6                 vote          1088.5                 peopl          1076.9
# 7                elect          1037.2                    go           972.1
# 8               #trump           777.0  #icelebratetrumpwith           833.7
# 9              protest           731.3                   one           714.9
# 10             support           662.6                    us           670.3
# 11   #hillaryforprison           623.1                 voter           646.8
# 12            american           609.7                 still           602.8
# 13                anti           606.3                 would           570.5
# 14                 say           594.2                  time           568.8
# 15             america           561.6                   win           554.2
# 16        #electionday           528.4                 obama           531.8
# 17             hillari           501.6                 black           502.5
# 18               right           499.9              democrat           473.4
# 19               media           486.3                   get           471.8
#
#                    Topic 4 words Topic 4 weights  ... Topic 10 words  \
# 0    #thingsthatshouldbecensored          1442.1  ...              �
# 1                          peopl          1346.8  ...           morn
# 2       #todolistbeforechristmas           981.2  ...             de
# 3                           know           883.3  ...             la
# 4                           talk           792.8  ...             ��
# 5                            day           756.3  ...             ❤️
# 6                           fuck           707.3  ...           good
# 7   #survivalguidetothanksgiving           687.2  ...              …
# 8                          thing           625.2  ...       challeng
# 9                           need           572.5  ...           lock
# 10                           buy           534.3  ...            rip
# 11                           say           477.5  ...             le
# 12                           get           475.6  ...             el
# 13                          year           472.4  ...         memori
# 14                          feel           458.4  ...          #юмор
# 15                          take           415.2  ...          dream
# 16                         everi           408.5  ...             en
# 17                         think           391.7  ...         spread
# 18                          make           387.6  ...            cat
# 19                          want           385.7  ...         доброй
#
#    Topic 10 weights            Topic 11 words Topic 11 weights Topic 12 words  \
# 0            3991.5                      make            717.7            man
# 1             466.5                     anoth            532.4          polic
# 2             397.1         #sometimesitsokto            497.5           kill
# 3             311.4        #itsunacceptableto            472.8          offic
# 4             282.6  #todolistbeforechristmas            471.8          woman
# 5             253.3                   #nodapl            419.7           year
# 6             227.6                     watch            394.3          state
# 7             184.0                      find            352.8         report
# 8             139.2                      miss            350.1            cop
# 9             132.8                     stand            344.0            old
# 10            129.7                       one            332.1         arrest
# 11            127.1                      open            307.3          shoot
# 12            122.0                     water            299.6           shot
# 13            120.7               #nowplaying            297.4          charg
# 14            117.1                      give            296.1           fire
# 15            115.0                      home            286.2              ’
# 16            110.1                     thank            284.2         attack
# 17             99.2                      want            276.0            fbi
# 18             91.4                     laugh            270.4          found
# 19             90.1                      gift            258.3          break
#
#    Topic 12 weights                Topic 13 words Topic 13 weights  \
# 0            1404.5                           get           2041.0
# 1            1184.6      #todolistbeforechristmas           1771.6
# 2            1036.1                        famili            809.4
# 3             683.3                            go            790.0
# 4             682.7                         happi            736.9
# 5             647.9                           one            713.6
# 6             583.1                          make            687.9
# 7             567.6                        friend            660.0
# 8             531.1                          love            588.0
# 9             526.5                     thanksgiv            520.8
# 10            524.0                      christma            489.7
# 11            513.5                         black            464.5
# 12            494.2                          keep            462.9
# 13            466.9                          list            454.1
# 14            448.5                          life            426.0
# 15            447.0                         world            407.2
# 16            440.1               #iamthankfulfor            312.7
# 17            434.0                          year            310.8
# 18            394.5  #survivalguidetothanksgiving            307.3
# 19            359.3                        friday            296.7
#
#    Topic 14 words Topic 14 weights
# 0               и           1750.7
# 1              на           1186.4
# 2              не           1155.1
# 3               с            950.3
# 4               …            811.9
# 5               я            744.4
# 6               в            724.1
# 7               —            595.4
# 8             это            584.2
# 9             как            555.1
# 10             ты            516.7
# 11        сегодня            421.6
# 12             мы            378.6
# 13            уже            347.8
# 14              а            319.2
# 15           день            315.1
# 16          когда            313.0
# 17              у            306.9
# 18            для            300.7
# 19            все            300.7
#
# [20 rows x 30 columns]

# %%
df_Aug2017['clean_tweet'] = df_Aug2017.tweet.apply(clean_tweet)

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.9, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')

tf = vectorizer.fit_transform(df_Aug2017['clean_tweet']).toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.decomposition import LatentDirichletAllocation

number_of_topics = 15

model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)

# %%
model.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=15, n_jobs=None, n_topics=None, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
no_top_words = 20
display_topics(model, tf_feature_names, no_top_words)
# Out:
#    Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights  \
# 0            die          1928.3            rt         14138.0
# 1             un          1425.1             …         10641.0
# 2            der          1312.1          like          2003.1
# 3            kim          1265.8           amp          1932.4
# 4           rice          1170.1         think          1759.2
# 5           jong          1084.1         peopl          1435.8
# 6            und          1036.1          want          1410.1
# 7           #imo           918.3          know          1404.5
# 8             da           885.1            go          1318.6
# 9          susan           850.9          look          1087.1
# 10           für           767.1           one          1069.4
# 11            im           739.1         trump          1065.4
# 12           auf           695.1           get          1005.0
# 13           ist           672.1      democrat          1004.2
# 14        unmask           641.5            rr           981.4
# 15           ein           616.1          need           966.8
# 16           mit           592.1         right           887.8
# 17           von           547.1          make           873.1
# 18        leaker           522.8           see           851.5
# 19             –           484.7          even           804.2
#
#       Topic 2 words Topic 2 weights   Topic 3 words Topic 3 weights  \
# 0                rt         24698.3              rt          5629.0
# 1                 …         10809.9               …          5151.5
# 2              #top          4442.2           trump          5105.7
# 3   realdonaldtrump          4015.0         violenc          1555.0
# 4              potu          3845.2            left          1498.7
# 5             #maga          3256.4        american          1423.8
# 6           america          2942.1             dem          1306.5
# 7             trump          2786.2         condemn          1240.1
# 8              #mar          2386.0             tri          1228.7
# 9           retweet          2160.8  debalwaystrump          1201.1
# 10           presid          2071.1          russia          1185.4
# 11              amp          1937.7             amp          1138.1
# 12            thank          1851.8            poll          1124.9
# 13          support          1613.6            hate          1080.5
# 14           follow          1441.6        democrat          1042.9
# 15             love          1172.8            agre           988.3
# 16               🇺🇸          1094.1             new           967.9
# 17         american          1007.8           media           950.7
# 18           foxnew           979.5   charlottesvil           942.0
# 19            pleas           974.1            fake           900.6
#
#     Topic 4 words Topic 4 weights  ... Topic 10 words Topic 10 weights  \
# 0               ’          9141.1  ...             rt           3388.7
# 1           trump          5331.8  ...          media           2560.2
# 2           break          3109.1  ...              …           2446.5
# 3             new          2696.4  ...          #maga           1916.4
# 4           video          2577.6  ...            amp           1346.7
# 5   charlottesvil          1891.3  ...           soro           1231.4
# 6         traitor          1687.9  ...          trump           1177.3
# 7          mccain          1612.2  ...            blm           1174.7
# 8             lol          1376.3  ...         antifa           1039.2
# 9           lynch          1288.0  ...        histori           1023.4
# 10             it          1243.5  ...       democrat            999.8
# 11         reveal          1066.4  ...          ignor            974.7
# 12           meet          1018.8  ...          liber            929.3
# 13           jeff           942.1  ...            kkk            897.6
# 14          flake           918.0  ...    #trumptrain            880.5
# 15           news           907.6  ...            lie            844.4
# 16        clinton           815.1  ...          georg            669.5
# 17           eric           793.3  ...         #pjnet            664.5
# 18           plan           716.2  ...           paid            659.2
# 19       bombshel           696.0  ...        hillari            646.8
#
#    Topic 11 words Topic 11 weights Topic 12 words Topic 12 weights  \
# 0               …           6816.6              в           3870.1
# 1          enlist           5016.1             на           1666.1
# 2         patriot           3103.2              и           1170.1
# 3              at           2563.1             ’t           1022.5
# 4             amp           2470.7              с            867.1
# 5            armi           2262.1           #ara            634.5
# 6              us           2106.4          #arre            634.5
# 7            join           1478.6             за            559.1
# 8           #usfa           1445.1              »            548.1
# 9           stand           1411.6             из            510.1
# 10          truth           1265.2             не            483.1
# 11        america            935.8              —            455.7
# 12        freedom            786.2            won            442.1
# 13          peopl            773.6         #alexa            436.9
# 14             gt            766.1        #alexdr            436.9
# 15          fight            754.3             по            432.1
# 16             rt            720.9         believ            429.1
# 17           read            697.7          break            375.2
# 18           need            683.9         releas            309.8
# 19            get            559.9              о            306.1
#
#      Topic 13 words Topic 13 weights Topic 14 words Topic 14 weights
# 0                rt          10489.7              \           6298.6
# 1                 …           7343.1        hedgebz           2429.1
# 2             #topl           3666.9         rewind           1979.0
# 3                us           1902.0         archiv           1568.1
# 4               amp           1753.9         rememb           1440.0
# 5              #may           1606.3           well           1082.5
# 6             trump           1203.4          curat           1074.1
# 7               get           1162.1            car            601.8
# 8   realdonaldtrump           1063.2         acosta            597.0
# 9               end            866.1            jim            578.1
# 10             time            820.3           fund            574.2
# 11             year            804.0         school            503.3
# 12               go            796.9              u            452.1
# 13                u            763.0           year            437.7
# 14              day            751.2         miller            408.9
# 15            great            681.4             rt            377.9
# 16             come            654.3        stephen            370.3
# 17           nation            643.5  politicalhedg            362.6
# 18            would            621.8        billion            340.7
# 19            could            607.9        chicago            335.5
#
# [20 rows x 30 columns]
